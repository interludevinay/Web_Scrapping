# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.4)

# %% [markdown]
# `Extracting the infomation`

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_table_data(table):
    rows = table.find_all("tr")
    data = []

    for row in rows:
        cells = row.find_all(["th", "td"])
        row_data = [cell.get_text(strip=True) for cell in cells]
        if row_data:
            data.append(row_data)

    return data

url = "https://en.wikipedia.org/wiki/Table_of_food_nutrients"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

tables = soup.find_all("table", class_="wikitable")

all_data = []

for table in tables:
    table_data = get_table_data(table)
    all_data.extend(table_data)

# Determine the maximum number of columns
max_columns = max(len(row) for row in all_data)

# Fill missing values with empty strings
all_data = [row + [''] * (max_columns - len(row)) for row in all_data]

# Create a DataFrame
columns = ["Food", "Measure", "Grams", "Calories", "Protein", "Carb", "Fiber", "Fat", "Sat_fat"]
df = pd.DataFrame(all_data, columns=columns)

# Print the DataFrame
print(df)
# Out:
#                            Food  Measure  Grams  Calories  Protein  Carb  \
# 0                Dairy products
# 1                          Food  Measure  Grams  Calories  Protein  Carb
# 2             Cows' milk, whole    1 qt.    976       660       32    48
# 3                          skim    1 qt.    984       360       36    52
# 4          Buttermilk, cultured    1 cup    246       127        9    13
# ..                          ...      ...    ...       ...      ...   ...
# 414         Fruit-flavored soda   12 oz.    346       161        0    42
# 415                  Ginger ale   12 oz.    346       105        0    28
# 416                   Root beer   12 oz.    346       140        0    35
# 417  Coffee, black, unsweetened    1 cup    230         3        t     1
# 418     Tea, clear, unsweetened    1 cup    230         4        0     1
#
#      Fiber  Fat  Sat_fat
# 0
# 1    Fiber  Fat  Sat_fat
# 2        0   40       36
# 3        0    t        t
# 4        0    5        4
# ..     ...  ...      ...
# 414      0    0        0
# 415      0    0        0
# 416      0    0        0
# 417      0    0        0
# 418      0    t        0
#
# [419 rows x 9 columns]

# %%
df['Food'].unique()
# Out:
# array(['Dairy products', 'Food', "Cows' milk, whole", 'skim',
#        'Buttermilk, cultured', 'Evaporated, undiluted', 'Fortified milk',
#        'Powdered milk, whole', 'skim, instant', 'skim, non-instant',
#        "Goats' milk, fresh", 'Malted milk', '(1/2 cup ice cream)',
#        'Cocoa', 'Yogurt, of partially', 'skim. milk', 'Milk pudding',
#        '(cornstarch)', 'Custard, baked', 'Ice cream, commercial',
#        'Ice milk, commercial', 'Cream, light,', 'or half-and-half',
#        'Cream, heavy,', 'or whipping', 'Cheese, cottage, creamed',
#        'uncreamed', 'Cheddar, orAmerican', 'Cheddar, grated cup',
#        'Cream cheese', 'Processed cheese', 'Roquefort type', 'Swiss',
#        'Eggs, boiled, poached,', 'or raw', 'Scrambled,omelet,',
#        'or fried', 'Yolksonly', 'Oils, fats and shortenings', 'Butter',
#        'or', 'Hydrogenated cooking fat', 'Lard',
#        'Margarine, 1/2 pound or', 'Margarine, 2 pat or', 'Mayonnaise',
#        'Oils', 'Corn,soy,peanut', 'orcottonseed', 'Olive',
#        'Safflower,sunflower', 'seed,walnut', 'Salad dressing', 'French',
#        'Thousand Island', 'Salt pork', 'Meat and poultry',
#        'Bacon, crisp, drained', 'Beef, chuck, pat-roasted',
#        'Hamburger, commercial', 'Ground lean', 'Roast beef,',
#        'oven-cooked', 'Steak, assirloin', 'Steak, lean, as round',
#        'Corned beef', 'Corned beef hash,', 'canned', 'Driedorchipped',
#        'Pot-pie, 4 1/2" diameter', 'Stew, withvegetables',
#        'chicken; broiled', 'Fried, breast or', 'leg and thigh', 'Roasted',
#        'Chicken livers, fried', 'Duck, domestic', 'Lamb, chop, broiled',
#        'Leg roasted', 'Shoulder, braised', 'Pork, chop, 1 thick',
#        'Ham, cured, and', 'pan-broiled', 'Ham, asluncheon meat',
#        'Ham, canned, spiced', 'Pork roast', 'Pork sausage, bulk',
#        'Turkey, roasted', 'Veal, cutlet, broiled', 'Roast',
#        'Fish and seafood', 'Clams, steamed or canned', 'Cod, broiled',
#        'Crab meat, cooked', 'Fish sticks, breaded,', 'fried',
#        'Flounder, baked', 'Haddock, fried', 'Halibut, broiled',
#        'Herring, kippered', 'Lobster, steamed', 'Mackerel, canned',
#        'Oysters, raw', 'or 1/2 cup', 'Oyster stew, made', 'with milk',
#        'Salmon, canned', 'Sardines, canned', 'Scallops, breaded, fried',
#        'Shad, baked', 'Shrimp, steamed', 'Swordfish, broiled',
#        'Tuna,canned, drained', 'Vegetables A-E', 'Artichoke, globe',
#        'Asparagus, green', 'Beans, green snap', 'Lima, green',
#        'Lima, dry, cooked', 'Navy, baked with pork', 'Red kidney, canned',
#        'Bean sprouts, uncooked', 'Beet greens, steamed',
#        'Beetroots, boiled', 'Broccoli, steamed',
#        'Brussels sprouts, steamedCabbage, ascoleslaw',
#        'Sauerkraut, canned', 'Steamed cabbage', 'Carrots,cooked,diced',
#        'Raw, grated', 'Strips, from raw', 'Cauliflower, steamed',
#        'Celery, cooked, diced', 'Stalk raw',
#        'Chard steamed, leaves and stalks', 'Collards,steamed leaves',
#        'Corn,steamed,', 'cooked or canned', 'Cucumbers, 1/8" slices',
#        'Dandelion greens, steamed', 'Eggplant,steamed',
#        'Endive(escarole)', 'Vegetables F-P', 'Kale, steamed',
#        'Kohlrabi, raw, sliced', 'Lambs quarters, steamed', 'Lentils',
#        'Lettuce, loose leaf, green', 'Iceberg', 'Mushrooms, cooked or',
#        'Mustard greens, steamed', 'Okra, diced, steamed',
#        'Onions, mature cooked', 'Raw, green', 'Parsley, chopped, raw',
#        'Parsnips, steamed', 'Peas, green, canned', 'Fresh, steamed',
#        'Frozen, heated', 'Split cooked', 'With carrots, frozen,',
#        'heated', 'Peppers, pimientos,', 'Raw, green, sweet',
#        'Stuffed with beef', 'and crumbs', 'Potatoes, baked',
#        'French-fried', 'Mashed with milk', 'and butter',
#        'Potatoes, pan-tried', 'Scalloped with cheese',
#        'Steamed before peeling', 'Potato chips', 'Vegetables R-Z',
#        'Radishes, raw', 'Rutabagas, diced', 'Soybeans, unseasoned',
#        'Spinach, steamed', 'Squash, summer', 'Winter, mashed',
#        'Sweet potatoes, baked', 'Candied', 'Tomatoes, canned whole',
#        'Raw, 2 by 2 1/2', 'Tomato juice, canned', 'Tomato catsup',
#        'Turnip greens, steamed', 'Turnips, steamed, sliced',
#        'Watercress, leaves and', 'stems, raw', 'Fruits A-F',
#        'Apple juice, fresh or', 'Apple vinegar', 'Apples, raw',
#        'Stewed or canned', 'Apricots, canned In syrup', 'Dried, uncooked',
#        'Fresh', 'Nectar, or juice', 'Avocado', 'Banana',
#        'Blackberries, fresh', 'Blueberries, canned', 'Cantaloupe',
#        'Cherries, canned, pitted', 'Fresh, raw', 'Cranberry sauce,',
#        'sweetened', 'Dates,dried', 'Figs, dried, large, 2" by 1"',
#        'with syrup', 'Fruit cocktail, canned', 'Fruits G-O',
#        'Grapefruit, canned', 'sections', 'Grapefruit, fresh,',
#        '5" diameter', 'Grapefruit juice', 'Grapes,American, as',
#        'Concord', 'European, as Muscat, Tokay', 'Grape juice, bottled',
#        'Lemon juice, fresh', 'Lemonade concentrate,', 'frozen',
#        'Limeade concentrate', 'Olives, green, canned', 'large',
#        'Ripe, canned, large', 'Oranges, fresh,', '3" diameter',
#        'Orange juice, fresh', 'Frozenconcentrate', 'Fruits P-Z',
#        'Papaya, fresh', 'Peaches, canned, sliced',
#        'Pears, canned, sweetened', 'Raw, 3 by 2V', 'Persimmons, Japanese',
#        'Pineapple, canned, sliced', 'Crushed', 'Raw, diced',
#        'Pineapple juice, canned', 'Plums, canned in syrup',
#        'Raw, 2" diameter', 'Prunes, cooked', 'Prune juice, canned*',
#        'Raisins, dried', 'Raspberries, frozen', 'Raw, red',
#        'Rhubarb, cooked,', 'Strawberries, frozen', 'Raw',
#        'Tangerines, fresh', 'Watermelon, 4 by 8"',
#        'Breads, cereals, and grains A-O', 'Biscuits, 2 1/2" diameters',
#        'Bran flakes', 'Bread, cracked wheat', 'Rye',
#        'White, 20 slices, or', 'Whole-wheat', 'Corn breadof whole',
#        'ground meal', 'Cornflakes', 'Corn grits, refined,', 'cooked',
#        'Corn meal, yellow', 'Crackers, graham', 'Soda, 2 1/2 square',
#        'Farina', 'Flour,soy, full fat', 'Wheat (all purpose)',
#        'Wheat (whole)', 'Macaroni, cooked', 'Baked with cheese',
#        'Muffinsofrefined flour', 'Noodles', 'Oatmeal, orrolled oats',
#        'Breads, cereals, and grains P-Z', 'Pancakes, buckwheat,',
#        '4" diam.', 'Wheat,refined flour,', 'Pizza,cheese, 1/8 of',
#        '14" diam.', 'Popcorn, withoiland', 'salt', 'Puffed rice',
#        'Puffed wheat,', 'presweetened', 'Rice, uncooked, brown',
#        'Converted', 'White', 'Rice flakes', 'Rice polish',
#        'Rolls, breakfast, sweet', 'of refined flour', 'whole-wheat',
#        'Spaghetti with meat sauce', 'with tomatoes and cheese',
#        'Spanish ricewith meat', 'Shredded wheat biscuit',
#        'Waffles, 1/2" x 4 1/2" x 5 1/2"', 'Wheat germ',
#        'Wheat-germ cereal,', 'toasted', 'Wheat-meal cereal,', 'unrefined',
#        'Wheat,unground,', 'Soups: canned and diluted', 'Bean soups',
#        'Beefand vegetable', 'Bouillon,broth,consommé', 'chickenorturkey',
#        'Clam chowder, without milk',
#        'Cream soups(asparagus,celery, etc.)', 'Noodle,rice,barley',
#        'Split-pea soup', 'Tomato soup, diluted w/milk',
#        'Vegetable(vegetarian)', 'Desserts and sweets', 'Apple betty',
#        'Bread puddingwithraisins', 'Cakes,angel food',
#        'Chocolate fudgew/icing', 'Cupcakewith icing',
#        'Fruit cake, 2" x 2" x 4"', 'Gingerbread, 2" cube',
#        'Plain, with no icing', 'Sponge cake, no icing', 'Candy,caramels',
#        'Chocolate creams', 'Fudge, plain, 1" x 1"', 'Hard candies',
#        'Marshmallows, large', 'Milk chocolate', 'Chocolate syrup',
#        'Doughnuts,cake type', 'Gelatin, made with water',
#        'Honey,strained honey, strained', 'Ice cream, see',
#        'Ices,lime,orange, etc.', 'Jams,marmalades,', 'preserves',
#        'Jellies', 'Molasses,blackstrap', 'Cane, refined',
#        'Pie, apple, 1/2 of', '9" diam. pie', 'Cherry', 'Custard',
#        'Lemon meringue', 'Mince', 'Pumpkin',
#        'Puddings(seeDairy products)', 'Sugar,beetorcane',
#        '3 teaspoons or', 'Brown, firm-packed, dark', 'Syrup,maple',
#        'table blends', 'Tapioca cream pudding', 'Nuts and seeds',
#        'Almonds, dried', 'roasted and salted', 'Brazil nuts;unsalted',
#        'Cashews, unsalted', 'Coconut, shredded,',
#        'Peanut butter, commercial', 'Peanut butter, natural',
#        'Peanuts, roasted', 'Pecans, raw, halves', 'Sesame seeds, dry',
#        'Sunflower seeds', 'Walnuts, English, raw', 'Beverages',
#        'Alcoholic', 'Beer(4% alcohol)', 'Gin,rum,vodka,whiskey(86 proof)',
#        'Wines,dessert(I 8.8% alcohol)', 'Table (12.2% alcohol)',
#        'Carbonated drinks', 'Artificially sweetened', 'Club soda',
#        'Cola drinks,sweetened', 'Fruit-flavored soda', 'Ginger ale',
#        'Root beer', 'Coffee, black, unsweetened',
#        'Tea, clear, unsweetened'], dtype=object)

# %%
df
# Out:
#                            Food  Measure  Grams  Calories  Protein  Carb  \
# 0                Dairy products
# 1                          Food  Measure  Grams  Calories  Protein  Carb
# 2             Cows' milk, whole    1 qt.    976       660       32    48
# 3                          skim    1 qt.    984       360       36    52
# 4          Buttermilk, cultured    1 cup    246       127        9    13
# ..                          ...      ...    ...       ...      ...   ...
# 414         Fruit-flavored soda   12 oz.    346       161        0    42
# 415                  Ginger ale   12 oz.    346       105        0    28
# 416                   Root beer   12 oz.    346       140        0    35
# 417  Coffee, black, unsweetened    1 cup    230         3        t     1
# 418     Tea, clear, unsweetened    1 cup    230         4        0     1
#
#      Fiber  Fat  Sat_fat
# 0
# 1    Fiber  Fat  Sat_fat
# 2        0   40       36
# 3        0    t        t
# 4        0    5        4
# ..     ...  ...      ...
# 414      0    0        0
# 415      0    0        0
# 416      0    0        0
# 417      0    0        0
# 418      0    t        0
#
# [419 rows x 9 columns]

# %% [markdown]
# `Giving the product_type to each product that they belongs to.`

# %%
df.loc[df.index[range(2,37)], 'Product Type'] = "Dairy"

# %%
df.loc[df.index[range(40,57)], 'Product Type'] = "Oils, fats and shortenings"

# %%
df.loc[df.index[range(60,92)], 'Product Type'] = "Meat and poultry"

# %%
df.loc[df.index[range(95,116)], 'Product Type'] = "Fish and seafood"

# %%
df.loc[df.index[range(119,199)], 'Product Type'] = "Vegetables"

# %%
df.loc[df.index[range(202,273)], 'Product Type'] = "Fruits"

# %%
df.loc[df.index[range(276,332)], 'Product Type'] = "Breads, cereals, and grains"

# %%
df.loc[df.index[range(335,344)], 'Product Type'] = "Soups: canned and diluted"

# %%
df.loc[df.index[range(347,387)], 'Product Type'] = "Desserts and sweets"

# %%
df.loc[df.index[range(390,402)], 'Product Type'] = "Nuts and seeds"

# %%
df.loc[df.index[range(405,418)], 'Product Type'] = "Beverages"

# %%
df
# Out:
#                            Food  Measure  Grams  Calories  Protein  Carb  \
# 0                Dairy products
# 1                          Food  Measure  Grams  Calories  Protein  Carb
# 2             Cows' milk, whole    1 qt.    976       660       32    48
# 3                          skim    1 qt.    984       360       36    52
# 4          Buttermilk, cultured    1 cup    246       127        9    13
# ..                          ...      ...    ...       ...      ...   ...
# 414         Fruit-flavored soda   12 oz.    346       161        0    42
# 415                  Ginger ale   12 oz.    346       105        0    28
# 416                   Root beer   12 oz.    346       140        0    35
# 417  Coffee, black, unsweetened    1 cup    230         3        t     1
# 418     Tea, clear, unsweetened    1 cup    230         4        0     1
#
#      Fiber  Fat  Sat_fat Product Type
# 0                                 NaN
# 1    Fiber  Fat  Sat_fat          NaN
# 2        0   40       36        Dairy
# 3        0    t        t        Dairy
# 4        0    5        4        Dairy
# ..     ...  ...      ...          ...
# 414      0    0        0    Beverages
# 415      0    0        0    Beverages
# 416      0    0        0    Beverages
# 417      0    0        0    Beverages
# 418      0    t        0          NaN
#
# [419 rows x 10 columns]

# %% [markdown]
# `Removing uneccessary data`
#
# `by just dropping the value which having Nan values`

# %%
df.dropna(inplace=True)

# %% [markdown]
# `After doing the above step we get our index in a non continuos form where which the value get's deleted`

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                            Food Measure  Grams Calories Protein Carb Fiber  \
# 0             Cows' milk, whole   1 qt.    976      660      32   48     0
# 1                          skim   1 qt.    984      360      36   52     0
# 2          Buttermilk, cultured   1 cup    246      127       9   13     0
# 3         Evaporated, undiluted   1 cup    252      345      16   24     0
# 4                Fortified milk  6 cups  1,419    1,373      89  119   1.4
# ..                          ...     ...    ...      ...     ...  ...   ...
# 381       Cola drinks,sweetened  12 oz.    346      137       0   38     0
# 382         Fruit-flavored soda  12 oz.    346      161       0   42     0
# 383                  Ginger ale  12 oz.    346      105       0   28     0
# 384                   Root beer  12 oz.    346      140       0   35     0
# 385  Coffee, black, unsweetened   1 cup    230        3       t    1     0
#
#     Fat Sat_fat Product Type
# 0    40      36        Dairy
# 1     t       t        Dairy
# 2     5       4        Dairy
# 3    20      18        Dairy
# 4    42      23        Dairy
# ..   ..     ...          ...
# 381   0       0    Beverages
# 382   0       0    Beverages
# 383   0       0    Beverages
# 384   0       0    Beverages
# 385   0       0    Beverages
#
# [386 rows x 10 columns]

# %% [markdown]
# `Converting it into DataFrame`

# %%
df.to_csv('Food_Nutrients.csv')

# %% [markdown]
# `<Requests 200> means our request is successfully granted.`
